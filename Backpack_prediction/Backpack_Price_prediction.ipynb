# %%
import pandas as pd

# %%
df_train = pd.read_csv('train.csv')

# %%
df_test = pd.read_csv('test.csv')

# %%
df_train.columns
# Out:
# Index(['id', 'Brand', 'Material', 'Size', 'Compartments', 'Laptop Compartment',
#        'Waterproof', 'Style', 'Color', 'Weight Capacity (kg)', 'Price'],
#       dtype='object')

# %%
df_train['Weight Capacity (kg)'].fillna(df_train['Weight Capacity (kg)'].mean(),inplace=True)
df_test['Weight Capacity (kg)'].fillna(df_test['Weight Capacity (kg)'].mean(),inplace=True)
df_train['Brand'].fillna(df_train['Brand'].mode()[0],inplace=True)
df_test['Brand'].fillna(df_test['Brand'].mode()[0],inplace=True)
df_train['Material'].fillna(df_train['Material'].mode()[0],inplace=True)
df_test['Material'].fillna(df_test['Material'].mode()[0],inplace=True)
df_train['Size'].fillna(df_train['Size'].mode()[0],inplace=True)
df_test['Size'].fillna(df_test['Size'].mode()[0],inplace=True)
df_train['Laptop Compartment'].fillna(df_train['Laptop Compartment'].mode()[0],inplace=True)
df_test['Laptop Compartment'].fillna(df_test['Laptop Compartment'].mode()[0],inplace=True)
df_train['Waterproof'].fillna(df_train['Waterproof'].mode()[0],inplace=True)
df_test['Waterproof'].fillna(df_test['Waterproof'].mode()[0],inplace=True)
df_train['Style'].fillna(df_train['Style'].mode()[0],inplace=True)
df_test['Style'].fillna(df_test['Style'].mode()[0],inplace=True)
df_train['Color'].fillna(df_train['Color'].mode()[0],inplace=True)
df_test['Color'].fillna(df_test['Color'].mode()[0],inplace=True)
# Out:
# C:\Users\91736\AppData\Local\Temp\ipykernel_24560\4016697978.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Weight Capacity (kg)'].fillna(df_train['Weight Capacity (kg)'].mean(),inplace=True)
# C:\Users\91736\AppData\Local\Temp\ipykernel_24560\4016697978.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df_test.isnull().sum()
# Out:
# id                      0
# Brand                   0
# Material                0
# Size                    0
# Compartments            0
# Laptop Compartment      0
# Waterproof              0
# Style                   0
# Color                   0
# Weight Capacity (kg)    0
# dtype: int64

# %%
df_train.isnull().sum()
# Out:
# id                      0
# Brand                   0
# Material                0
# Size                    0
# Compartments            0
# Laptop Compartment      0
# Waterproof              0
# Style                   0
# Color                   0
# Weight Capacity (kg)    0
# Price                   0
# dtype: int64

# %%
df_train.to_csv("train_cleaned.csv")
df_test.to_csv('tst_cleaned.csv')

# %%
df_train
# Out:
#             id         Brand Material    Size  Compartments  \
# 0            0      Jansport  Leather  Medium           7.0
# 1            1      Jansport   Canvas   Small          10.0
# 2            2  Under Armour  Leather   Small           2.0
# 3            3          Nike    Nylon   Small           8.0
# 4            4        Adidas   Canvas  Medium           1.0
# ...        ...           ...      ...     ...           ...
# 299995  299995        Adidas  Leather   Small           9.0
# 299996  299996      Jansport  Leather   Large           6.0
# 299997  299997          Puma   Canvas   Large           9.0
# 299998  299998        Adidas    Nylon   Small           1.0
# 299999  299999  Under Armour   Canvas   Small           2.0
#
#        Laptop Compartment Waterproof      Style  Color  Weight Capacity (kg)  \
# 0                     Yes         No       Tote  Black             11.611723
# 1                     Yes        Yes  Messenger  Green             27.078537
# ...

# %%
x = df_train.drop(columns=['Price']) #Independent Columns
y = df_train['Price']
